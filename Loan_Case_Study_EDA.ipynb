# %%
#This is the part of pre requisite
#that is importing libraries like numpy,pandas,seaborn,matplotlib
#importing numpy
import numpy as np
print('numpy version\t:',np.__version__)
#importing pandas
import pandas as pd
print('pandas version\t:',pd.__version__)
# importing seaborn for advanced visualization
import seaborn as sns
print('seaborn version\t:',sns.__version__)
# importing matplotlib
import matplotlib as mlt
print('matplotlib version\t:',mlt.__version__)
# Out:
# numpy version	: 1.16.2
# pandas version	: 0.24.2
# seaborn version	: 0.9.0
# matplotlib version	: 3.0.3

# %%
#This is a part of data sourcing
#part1
#This would help to load the csv file as dataframe, provide its shape and info
import pandas as pd
import numpy as np
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandata
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000       4975.00000
# 1      1077430    1314167       2500         2500       2500.00000
# 2      1077175    1313524       2400         2400       2400.00000
# 3      1076863    1277178      10000        10000      10000.00000
# 4      1075358    1311748       3000         3000       3000.00000
# 5      1075269    1311441       5000         5000       5000.00000
# 6      1069639    1304742       7000         7000       7000.00000
# 7      1072053    1288686       3000         3000       3000.00000
# 8      1071795    1306957       5600         5600       5600.00000
# 9      1071570    1306721       5375         5375       5350.00000
# 10     1070078    1305201       6500         6500       6500.00000
# 11     1069908    1305008      12000        12000      12000.00000
# 12     1064687    1298717       9000         9000       9000.00000
# ...

# %%
#This is a part of data sourcing
#part2
#Displaying the top ten rows of the dataframe
import pandas as pd
import numpy as np
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandata.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# ...

# %%
#This is a part of data sourcing
#part3
#Displaying the shape and indormation about the dataframe
import pandas as pd
import numpy as np
loandata = pd.read_csv('loan.csv',encoding='utf-8')
print(loandata.shape)
print(loandata.info())
# Out:
# (39717, 111)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB
# None

# %%
#This is a part of data cleaning
#part1
#Checking and displaying bar graph of the number of null values in different columns of the data set
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
numofNA_loandata = loandata.isnull().sum()
print(numofNA_loandata)
plt.figure(figsize=(20,4))
plt.title('List of Colums with NA values ranging from 0% to 100%')
plt.xlabel('Column_Names of Dataset')
plt.ylabel('NA Values in columns')
barplot_navalues = numofNA_loandata.plot.bar(x='column_names', y='NA Values of columns',label = 'Value bars')
plt.legend()
plt.show()
# Out:
# id                                    0
# member_id                             0
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# sub_grade                             0
# emp_title                          2459
# emp_length                         1075
# home_ownership                        0
# annual_inc                            0
# verification_status                   0
# issue_d                               0
# loan_status                           0
# pymnt_plan                            0
# url                                   0
# desc                              12940
# purpose                               0
# title                                11
# zip_code                              0
# ...

# %%
#This is a part of data cleaning
#part2
#Removing columns with 100% null values and displaying the rest in bar graph.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanullremovesum = loandatanullremove.isnull().sum()
print(loandatanullremovesum)
plt.figure(figsize=(20,4))
plt.title('List of Colums with NA values ranging from 0% to  less than 100%')
plt.xlabel('Column_Names of Dataset')
plt.ylabel('NA Values in columns')
barplot_navalues = loandatanullremovesum.plot.bar(x='column_names', y='NA Values of columns',label = 'Value bars')
plt.legend()
plt.show()
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# ...

# %%
#This is a part of data cleaning
#part3
#Displaying the number of null values in terms of percentage
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanullremovepercent = round((loandatanullremove.isnull().sum()/len(loandatanullremove))*100,2)
print(loandatanullremovepercent)
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
# term                           0.00
# int_rate                       0.00
# installment                    0.00
# grade                          0.00
# sub_grade                      0.00
# emp_title                      6.19
# emp_length                     2.71
# home_ownership                 0.00
# annual_inc                     0.00
# verification_status            0.00
# issue_d                        0.00
# loan_status                    0.00
# pymnt_plan                     0.00
# url                            0.00
# ...

# %%
#This is a part of data cleaning
#part4
#Removing column 'desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d' as they have more than 30% null columns
#and they do not provide any help in analysis
#dropping of chargeoff_within_12_mths,pub_rec_bankruptcies,tax_liens,collections_12_mths_ex_med as this column has one unique values and this did not hellp in any analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','title','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med'],axis = 1)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
print(loandatanulldropcolumn.shape)
print(loandatanullremovepercent)
# Out:
# (39717, 49)
# id                         0.00
# member_id                  0.00
# loan_amnt                  0.00
# funded_amnt                0.00
# funded_amnt_inv            0.00
# term                       0.00
# int_rate                   0.00
# installment                0.00
# grade                      0.00
# sub_grade                  0.00
# emp_title                  6.19
# emp_length                 2.71
# home_ownership             0.00
# annual_inc                 0.00
# verification_status        0.00
# issue_d                    0.00
# loan_status                0.00
# pymnt_plan                 0.00
# url                        0.00
# purpose                    0.00
# title                      0.03
# zip_code                   0.00
# addr_state                 0.00
# dti                        0.00
# delinq_2yrs                0.00
# earliest_cr_line           0.00
# inq_last_6mths             0.00
# open_acc                   0.00
# pub_rec                    0.00
# ...

# %%
#This is a part of data cleaning
#part4
#This would make sure that there are no column with null values in the final dataframe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','title','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn["last_credit_pull_d"].fillna("Mar-15", inplace = True)
loandatanulldropcolumn["emp_length"].fillna("4 years", inplace = True)
loandatanulldropcolumn["last_pymnt_d"].fillna("Apr-13", inplace = True)
loandatanulldropcolumn["revol_util"].fillna("49.30%", inplace = True)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
loandatanullremovepercent
# Out:
# id                         0.0
# member_id                  0.0
# loan_amnt                  0.0
# funded_amnt                0.0
# funded_amnt_inv            0.0
# term                       0.0
# int_rate                   0.0
# installment                0.0
# grade                      0.0
# sub_grade                  0.0
# emp_length                 0.0
# home_ownership             0.0
# annual_inc                 0.0
# verification_status        0.0
# issue_d                    0.0
# loan_status                0.0
# pymnt_plan                 0.0
# url                        0.0
# purpose                    0.0
# zip_code                   0.0
# addr_state                 0.0
# dti                        0.0
# delinq_2yrs                0.0
# earliest_cr_line           0.0
# inq_last_6mths             0.0
# open_acc                   0.0
# pub_rec                    0.0
# revol_bal                  0.0
# revol_util                 0.0
# total_acc                  0.0
# ...

# %%
#This is a part of univariate analysis
#part1
#In this part we are checking for the mean,median,mode and other values of the final dataframe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','title','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn["last_credit_pull_d"].fillna("Mar-15", inplace = True)
loandatanulldropcolumn["emp_length"].fillna("4 years", inplace = True)
loandatanulldropcolumn["last_pymnt_d"].fillna("Apr-13", inplace = True)
loandatanulldropcolumn["revol_util"].fillna("49.30%", inplace = True)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
round(loandatanulldropcolumn.describe(),2)
# Out:
#                id   member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# count    39717.00    39717.00   39717.00     39717.00         39717.00
# mean    683131.91   850463.56   11219.44     10947.71         10397.45
# std     210694.13   265678.31    7456.67      7187.24          7128.45
# min      54734.00    70699.00     500.00       500.00             0.00
# 25%     516221.00   666780.00    5500.00      5400.00          5000.00
# 50%     665665.00   850812.00   10000.00      9600.00          8975.00
# 75%     837755.00  1047339.00   15000.00     15000.00         14400.00
# max    1077501.00  1314167.00   35000.00     35000.00         35000.00
#
#        installment  annual_inc       dti  delinq_2yrs  inq_last_6mths  ...  \
# count     39717.00    39717.00  39717.00     39717.00        39717.00  ...
# mean        324.56    68968.93     13.32         0.15            0.87  ...
# std         208.87    63793.77      6.68         0.49            1.07  ...
# ...

# %%
#This is a part of univariate analysis
#part2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','title','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn["last_credit_pull_d"].fillna("Mar-15", inplace = True)
loandatanulldropcolumn["emp_length"].fillna("4 years", inplace = True)
loandatanulldropcolumn["last_pymnt_d"].fillna("Apr-13", inplace = True)
loandatanulldropcolumn["revol_util"].fillna("49.30%", inplace = True)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
loan_status_display = loandatanulldropcolumn.groupby("loan_status").agg({"id":"count"})
loan_status_display.boxplot()
loan_status_display.plot.bar()

# %%
#This is a part of univariate analysis
#part3
#find total number of defaulters by grouping the data as per loan_status
#This would also help to analise whether the firm is making correct discision in terms of giving loan to the individuals.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn["last_credit_pull_d"].fillna("Mar-15", inplace = True)
loandatanulldropcolumn["emp_length"].fillna("4 years", inplace = True)
loandatanulldropcolumn["last_pymnt_d"].fillna("Apr-13", inplace = True)
loandatanulldropcolumn["revol_util"].fillna("49.30%", inplace = True)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
verification_display = loandatanulldropcolumn.groupby("purpose").agg({"id":"count"})
verification_display.boxplot()
verification_display.plot.bar()
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#This is a part of univariate analysis
#part4
#find total number of defaulters by grouping the data as per loan_status
#This would also help to analise whether the firm is making correct discision in terms of giving loan to the individuals.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
verification_display = loandatanulldropcolumn.groupby(["purpose","loan_status"]).agg({"id":"count"})
print(verification_display)
verification_display.plot.bar(figsize=(20,4))
# Out:
#                                    id
# purpose            loan_status
# car                Charged Off    160
#                    Current         50
#                    Fully Paid    1339
# credit_card        Charged Off    542
#                    Current        103
#                    Fully Paid    4485
# debt_consolidation Charged Off   2767
#                    Current        586
#                    Fully Paid   15288
# educational        Charged Off     56
#                    Fully Paid     269
# home_improvement   Charged Off    347
#                    Current        101
#                    Fully Paid    2528
# house              Charged Off     59
#                    Current         14
#                    Fully Paid     308
# major_purchase     Charged Off    222
#                    Current         37
#                    Fully Paid    1928
# medical            Charged Off    106
#                    Current         12
#                    Fully Paid     575
# ...

# %%
#This is a part of univariate analysis
#part4
#find total number of defaulters by grouping the data as per loan_status
#This would also help to analise whether the firm is making correct discision in terms of giving loan to the individuals.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
verification_display = loandatanulldropcolumn.groupby(["purpose","loan_status"]).agg({"id":"count"})
loan_data_by_purpose = loandatanulldropcolumn.groupby(["purpose"]).agg({"id":"count"})
loan_data_by_purpose = loan_data_by_purpose.rename(columns={"id":"total_count"})
loan_data_by_purpose = loan_data_by_purpose.reset_index()
verification_display = verification_display.reset_index()
verification_display
loan_df = pd.merge(loan_data_by_purpose,verification_display,how = 'inner',on="purpose")
loan_df["percentage_loan_distribution"] = loan_df.id*100/loan_df.total_count
loan_df[loan_df.loan_status=="Charged Off"].sort_values(by="percentage_loan_distribution",ascending=False)
# Out:
#                purpose  total_count  loan_status    id  \
# 32      small_business         1828  Charged Off   475
# 29    renewable_energy          103  Charged Off    19
# 9          educational          325  Charged Off    56
# 26               other         3993  Charged Off   633
# 23              moving          583  Charged Off    92
# 14               house          381  Charged Off    59
# 20             medical          693  Charged Off   106
# 6   debt_consolidation        18641  Charged Off  2767
# 35            vacation          381  Charged Off    53
# 11    home_improvement         2976  Charged Off   347
# 3          credit_card         5130  Charged Off   542
# 0                  car         1549  Charged Off   160
# 17      major_purchase         2187  Charged Off   222
# 38             wedding          947  Charged Off    96
#
#     percentage_loan_distribution
# 32                     25.984683
# 29                     18.446602
# 9                      17.230769
# ...

# %%
#This is a part of univariate analysis
#part4
loan_data_by_ver_loan_status = loandatanulldropcolumn.groupby(["verification_status","loan_status"]).agg({"id":["count"]})
loan_data_by_ver = loandatanulldropcolumn.groupby(["verification_status"]).agg({"id":["count"]})
loan_data_by_ver_loan_status
loan_data_by_ver_loan_status.columns = ["_".join(x) for x in loan_data_by_ver_loan_status.columns.ravel()]
loan_data_by_ver_loan_status = loan_data_by_ver_loan_status.reset_index()
loan_data_by_ver_loan_status

loan_data_by_ver.columns = ["_".join(x) for x in loan_data_by_ver.columns.ravel()]
loan_data_by_ver = loan_data_by_ver.rename(index=str,columns={"id_count":"total_count"})
loan_data_by_ver = loan_data_by_ver.reset_index()
loan_data_by_ver

loan_df1 = pd.merge(loan_data_by_ver_loan_status,loan_data_by_ver,how="inner",on="verification_status")
loan_df1["defaulter_percentage"] = loan_df1.id_count*100/loan_df1.total_count
loan_df1
# Out:
#   verification_status  loan_status  id_count  total_count  \
# 0        Not Verified  Charged Off      2142        16921
# 1        Not Verified      Current       227        16921
# 2        Not Verified   Fully Paid     14552        16921
# 3     Source Verified  Charged Off      1434         9987
# 4     Source Verified      Current       310         9987
# 5     Source Verified   Fully Paid      8243         9987
# 6            Verified  Charged Off      2051        12809
# 7            Verified      Current       603        12809
# 8            Verified   Fully Paid     10155        12809
#
#    defaulter_percentage
# 0             12.658826
# 1              1.341528
# 2             85.999645
# 3             14.358666
# 4              3.104035
# 5             82.537298
# 6             16.012179
# 7              4.707627
# 8             79.280194

# %%
#This is a part of univariate analysis
#part5
#find total number of defaulters by grouping the data as per loan_status
#This would also help to analise whether the firm is making correct discision in terms of giving loan to the individuals.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
verification_display = loandatanulldropcolumn.groupby("verification_status").agg({"id":"count"})
verification_display.boxplot()
verification_display.plot.bar()
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#This is a part of univariate analysis
#part6
#find total number of defaulters by grouping the data as per loan_status
#This would also help to analise whether the firm is making profit or loss after disburseing loans.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med'],axis = 1)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
(loandatanulldropcolumn.groupby(["loan_status"]).agg({"loan_amnt":"sum","total_pymnt":"sum","collection_recovery_fee":"sum"})).plot.line()
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#This is a part of univariate analysis
#part7
#Loss because of charged off loans - 29,633,774.894569
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
calculating_loss = loandatanulldropcolumn.groupby(["loan_status"]).agg({"loan_amnt":"sum","total_pymnt":"sum","recoveries":"sum","collection_recovery_fee":"sum"})
calculating_loss = calculating_loss.reset_index()
calculating_loss_charged_off = calculating_loss[calculating_loss.loan_status=="Charged Off"]
loss = (calculating_loss_charged_off.loan_amnt-(calculating_loss_charged_off.collection_recovery_fee+calculating_loss_charged_off.total_pymnt))
round(loss,2)
#pd.options.display.float_format='{:20,.6f}'.format
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0    29141041.35
# dtype: float64

# %%
#This is a part of univariate analysis
#part8
#profitability of the loan business
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanullremovepercent = round((loandatanulldropcolumn.isnull().sum()/len(loandatanullremove))*100,2)
calculating_profit = loandatanulldropcolumn.groupby(["loan_status"]).agg({"loan_amnt":"sum","total_pymnt":"sum","recoveries":"sum","collection_recovery_fee":"sum"})
calculating_profit = calculating_profit.reset_index()
profit = (calculating_profit.total_pymnt+calculating_profit.collection_recovery_fee - calculating_profit.loan_amnt).sum()
round(profit,2)
# Out:
# 37594477.47

# %%
#This is a part of univariate analysis
#part9
#mean,max,media,sd, quantiles of continuous dimensions 
#Loss because of charged off loans - 29,633,774.894569
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.describe(include="all")
# Out:
#                   id     member_id     loan_amnt   funded_amnt  \
# count   3.971700e+04  3.971700e+04  39717.000000  39717.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std     2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min     5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%     5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%     6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%     8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max     1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#         funded_amnt_inv        term int_rate   installment  grade sub_grade  \
# count      39717.000000       39717    39717  39717.000000  39717     39717
# ...

# %%
#This is a part of univariate analysis
#part10
#find the box plot for loan amount
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.boxplot(["loan_amnt"])

# %%
#This is a part of univariate analysis
#part11
#find the box plot for loan amount
#It shows the 25th to 75th percentile is within 0 to 1000000
#It also has outliers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
plt.ylim(0, 600000)
anual_income = loandatanulldropcolumn.boxplot(["annual_inc"],figsize=(20,10))
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#This is a part of univariate analysis
#part12
#find the box plot for loan amount
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.boxplot(["installment"])
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#This is a part of univariate analysis
#part13
#It shows the different borrowers with different grades
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.grade.value_counts()
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: grade, dtype: int64

# %%
#This is a part of univariate analysis
#part14
#It shows the calculated number of home ownership of different borrower
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.home_ownership.value_counts()
# Out:
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER          98
# NONE            3
# Name: home_ownership, dtype: int64

# %%
#This is a part of univariate analysis
#part15
#It shows the plot of home ownership of different borrower
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.home_ownership.value_counts().plot.bar()

# %%
#This is a part of univariate analysis
#part15
#It shows the calculated number of the verification status of the loan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.verification_status.value_counts()
# Out:
# Not Verified       16921
# Verified           12809
# Source Verified     9987
# Name: verification_status, dtype: int64

# %%
#This is a part of univariate analysis
#part16
#It shows the calculated number of the purpose of loan of different borrowers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
loandatanulldropcolumn.purpose.value_counts()
# Out:
# debt_consolidation    18641
# credit_card            5130
# other                  3993
# home_improvement       2976
# major_purchase         2187
# small_business         1828
# car                    1549
# wedding                 947
# medical                 693
# moving                  583
# vacation                381
# house                   381
# educational             325
# renewable_energy        103
# Name: purpose, dtype: int64

# %%
#This is a part of univariate analysis
#part17
#It shows the frequency distribution of values of different columns like annual income,installment,funded amount,loan amount
#total payment,total recorded principle.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)

col_names = ['installment', 'annual_inc','loan_amnt','funded_amnt','funded_amnt_inv','total_pymnt_inv','total_rec_prncp']

fig, ax = plt.subplots(len(col_names), figsize=(20,12))

for i, col_val in enumerate(col_names):

    sns.distplot(loandatanulldropcolumn[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)

plt.show()

# %%
#This is a part of univariate analysis
#part18
#Checking for the plot where annual income is less than 83000 the 75th quartile.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
pd.options.display.float_format='{:20,.2f}'.format
annual_income_describe = loandatanulldropcolumn["annual_inc"].describe()
print(annual_income_describe)
loandatanulldropcolumn[loandatanulldropcolumn["annual_inc"] < 83000].annual_inc.hist()
# Out:
# count              39,717.00
# mean               68,968.93
# std                63,793.77
# min                 4,000.00
# 25%                40,404.00
# 50%                59,000.00
# 75%                82,300.00
# max             6,000,000.00
# Name: annual_inc, dtype: float64

# %%
#This is a part of univariate analysis
#part19
#convert loan_status column to categorical type and then perform label encoding
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes

loandatanulldropcolumn
# Out:
#             id  member_id  loan_amnt  funded_amnt      funded_amnt_inv  \
# 0      1077501    1296599       5000         5000             4,975.00
# 1      1077430    1314167       2500         2500             2,500.00
# 2      1077175    1313524       2400         2400             2,400.00
# 3      1076863    1277178      10000        10000            10,000.00
# 4      1075358    1311748       3000         3000             3,000.00
# 5      1075269    1311441       5000         5000             5,000.00
# 6      1069639    1304742       7000         7000             7,000.00
# 7      1072053    1288686       3000         3000             3,000.00
# 8      1071795    1306957       5600         5600             5,600.00
# 9      1071570    1306721       5375         5375             5,350.00
# 10     1070078    1305201       6500         6500             6,500.00
# 11     1069908    1305008      12000        12000            12,000.00
# ...

# %%
#This is a part of univariate analysis
#part19
#Changing the values to categorical data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
categorical_features
# Out:
# Index(['term', 'int_rate', 'grade', 'sub_grade', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'url', 'purpose', 'title', 'zip_code', 'addr_state',
#        'earliest_cr_line', 'revol_util', 'initial_list_status', 'last_pymnt_d',
#        'last_credit_pull_d', 'application_type'],
#       dtype='object')

# %%
#plot violinplots for categorical columns distribution
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="term",y="loan_status",data=loan_data_categorical)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#interest rate values are distributed vaguley so replace % and make this column numeric
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="int_rate",y="loan_status",data=loan_data_categorical)
loandatanulldropcolumn["int_rate"] = loandatanulldropcolumn["int_rate"].str.replace("%","").astype("float64")

# %%
#Plot showing loan status vs grade of the borrower.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="grade",y="loan_status",data=loan_data_categorical)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Plot showing loan status versur sub grade of the borrower.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="sub_grade",y="loan_status",data=loan_data_categorical)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#PLot showing the variation of employee length versur loan status.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="emp_length",y="loan_status",data=loan_data_categorical)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Plot of loan status versus the home ownership
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="home_ownership",y="loan_status",data=loan_data_categorical)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#pymnt_plan has a constant value 0. Its better to drop this column as there is no variation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="verification_status",y="loan_status",data=loan_data_categorical)
sns.catplot(x="pymnt_plan",y="loan_status",data=loan_data_categorical)
loandatanulldropcolumn = loandatanulldropcolumn.drop(["pymnt_plan"],axis=1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="purpose",y="loan_status",data=loan_data_categorical)

# %%
#'title', 'zip_code',  'addr_state', 'earliest_cr_line', 'revol_util', 'initial_list_status','last_pymnt_d','next_pymnt_d','last_credit_pull_d',
# 'application_type'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
loan_data_categorical = loandatanulldropcolumn.copy(deep=True)
for i, col_val in enumerate(categorical_features):
    loan_data_categorical[col_val] = loan_data_categorical[col_val].astype('category')
    loan_data_categorical[col_val]  = loan_data_categorical[col_val].cat.codes
sns.catplot(x="earliest_cr_line",y="loan_status",data=loan_data_categorical)
loandatanulldropcolumn.earliest_cr_line
# Out:
# 0        Jan-85
# 1        Apr-99
# 2        Nov-01
# 3        Feb-96
# 4        Jan-96
# 5        Nov-04
# 6        Jul-05
# 7        Jan-07
# 8        Apr-04
# 9        Sep-04
# 10       Jan-98
# 11       Oct-89
# 12       Apr-04
# 13       Jul-03
# 14       May-91
# 15       Sep-07
# 16       Oct-98
# 17       Aug-93
# 18       Oct-03
# 19       Jan-01
# 20       Nov-97
# 21       Feb-83
# 22       Jul-85
# 23       Apr-03
# 24       Jun-01
# 25       Feb-02
# 26       Oct-03
# 27       Oct-03
# 28       Aug-84
# 29       Nov-06
#           ...
# 39687    Apr-95
# 39688    Jan-96
# 39689    May-04
# 39690    Feb-69
# 39691    Aug-03
# 39692    Apr-03
# 39693    Dec-02
# 39694    Dec-87
# 39695    Jul-00
# 39696    Jan-00
# 39697    Sep-03
# 39698    Jan-99
# 39699    Jun-95
# 39700    Mar-89
# 39701    Feb-92
# 39702    Apr-93
# 39703    Feb-97
# 39704    Sep-00
# 39705    Oct-97
# 39706    Jun-96
# 39707    Feb-95
# 39708    Aug-95
# 39709    Jul-96
# 39710    Oct-97
# ...

# %%
#Get all numeric columns and check columns in which sd = 0
#drop tax_liens column
#loan_data = loan_data.drop("tax_liens",axis=1)
#There are two columns in which most of the values are 0 - out_prncp & out_prncp_inv, recoveries,collection_recovery_fee,total_rec_late_fee
#pub_rec_bankruptcies,
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
df_num = loandatanulldropcolumn.select_dtypes(include=[np.float,np.int8])
df_num_columns = df_num.columns
df_non_num = loandatanulldropcolumn.select_dtypes(exclude=[np.float]).columns
X = df_num.iloc[:,0:75]  #independent columns
y = pd.DataFrame(loandatanulldropcolumn.loc[:,"loan_status"])
df_num.describe()
df_num.iloc[:,0:2].hist(bins=200)
df_num.iloc[:,2:5].hist(bins=200)
df_num.iloc[:,5:7].hist(bins=200)
df_num.iloc[:,7:9].hist(bins=200)
df_num.iloc[:,9:11].hist(bins=200)
df_num.iloc[:,11:13].hist(bins=200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AE824AF048>,
# ...
#       dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
fig, ax = plt.subplots(len(df_num_columns), figsize=(200,200))

for i, col_val in enumerate(df_num_columns):
    data = loandatanulldropcolumn[col_val].dropna()
    sns.distplot(data, hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)

plt.show()

# %%
#skewness  - in case of skewness machine learning model will be biased.
#collect more data for skewed side
#what do we do? - take a log of the value
#normalize the variables in order to avoid biasness in the prediction
#check for each and every columns
#df_num = df_num.fillna(df_num.median)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
df_num.median
# Out:
# <bound method DataFrame.median of            funded_amnt_inv          installment           annual_inc  \
# 0                 4,975.00               162.87            24,000.00
# 1                 2,500.00                59.83            30,000.00
# 2                 2,400.00                84.33            12,252.00
# 3                10,000.00               339.31            49,200.00
# 4                 3,000.00                67.79            80,000.00
# 5                 5,000.00               156.46            36,000.00
# 6                 7,000.00               170.08            47,004.00
# 7                 3,000.00               109.43            48,000.00
# 8                 5,600.00               152.39            40,000.00
# 9                 5,350.00               121.45            15,000.00
# 10                6,500.00               153.45            72,000.00
# 11               12,000.00               402.54            75,000.00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med','emp_title'],axis = 1)
df_num.columns
# Out:
# Index(['funded_amnt_inv', 'installment', 'annual_inc', 'dti', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt'],
#       dtype='object')

# %%
#bivariate analysis find the correlation between different columns
#identify the clusters of highly positive correlated and highly negative corelated clusters
#Observations:
#highly positive correlated variables cluster - 1 - total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int
#highly positive correlated variables cluster - 2 - loan_amnt, funded_amnt, funded_amnt_inv, installment
#highly positive correlated variables cluster - 3 - id, member_id - not useful
#highly positive correlated variables cluster - 4 - mths_since_last_delinq, delinq_2yrs
#highly positive correlated variables cluster - 5 - total_acct, open_acc
#highly negative correlated variables cluster - 6 - mths_since_last_delinq, delinq_2yrs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med'],axis = 1)
corrmat = loandatanulldropcolumn.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(loandatanulldropcolumn[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#heat map on important numeric features only
#total_rec_prncp,recoveries,collection_recovery_fee,total_pymnt_inv,out_prncp_inv,out_prncp,installment,total_pymnt_inv,funded_amnt_inv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med'],axis = 1)
#from the above heat map its clear that few columns are absolutely not required
#collections_12_mths_ex_med, policy_code, acc_now_delinq,chargeoff_within_12_mths and delinq_amnt
#loan_data = loan_data.drop(["collections_12_mths_ex_med", "policy_code", "acc_now_delinq","chargeoff_within_12_mths","delinq_amnt"],axis=1)
corrmat = loandatanulldropcolumn.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(loandatanulldropcolumn[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#heat map on important numeric features only
#total_rec_prncp,recoveries,collection_recovery_fee,total_pymnt_inv,out_prncp_inv,out_prncp,installment,total_pymnt_inv,funded_amnt_inv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med'],axis = 1)
imp_numeric_features = loandatanulldropcolumn[["total_rec_prncp","recoveries","collection_recovery_fee","total_pymnt_inv","out_prncp_inv","out_prncp","installment","total_pymnt_inv","funded_amnt_inv"]]
corrmat = imp_numeric_features.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(loandatanulldropcolumn[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#clean the last_credit_pull_d
#There are two values 
#drived metrics using type as a driver
#following columns are used as base columns - last_credit_pull_d, last_pymnt_d, earliest_cr_line_year, issue_d
from dateutil.parser import parse
#loan_data["last_credit_pull_d"].dropna().unique()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandata = pd.read_csv('loan.csv',encoding='utf-8')
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn = loandatanullremove.drop(['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','chargeoff_within_12_mths','pub_rec_bankruptcies','tax_liens','collections_12_mths_ex_med'],axis = 1)

temp = loandatanulldropcolumn["last_credit_pull_d"].dropna().apply(lambda x : parse(x))
loandatanulldropcolumn["last_credit_pull_d_year"] = pd.to_datetime(temp).dt.year
loandatanulldropcolumn["last_credit_pull_d_month"] = pd.to_datetime(temp).dt.month


temp = loandatanulldropcolumn["last_pymnt_d"].dropna().apply(lambda x : parse(x))
loandatanulldropcolumn["last_pymnt_d_year"] = pd.to_datetime(temp).dt.year
loandatanulldropcolumn["last_pymnt_d_month"] = pd.to_datetime(temp).dt.month

#temp = loan_data["earliest_cr_line"].dropna().apply(lambda x : parse(x))
#loan_data["earliest_cr_line_year"] = pd.to_datetime(temp).dt.year
#loan_data["earliest_cr_line_month"] = pd.to_datetime(temp).dt.month

temp = loandatanulldropcolumn["issue_d"].dropna().apply(lambda x : parse(x))
loandatanulldropcolumn["issue_d"] = pd.to_datetime(temp).dt.year
loandatanulldropcolumn["issue_d"] = pd.to_datetime(temp).dt.month

categorical_features = loandatanulldropcolumn.dtypes[loandatanulldropcolumn.dtypes=="object"].index
for i, col_val in enumerate(categorical_features):
    loandatanulldropcolumn[col_val] = loandatanulldropcolumn[col_val].astype('category')
    loandatanulldropcolumn[col_val]  = loandatanulldropcolumn[col_val].cat.codes
loandatanulldropcolumn
# Out:
#             id  member_id  loan_amnt  funded_amnt      funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000             4,975.00     0
# 1      1077430    1314167       2500         2500             2,500.00     1
# 2      1077175    1313524       2400         2400             2,400.00     0
# 3      1076863    1277178      10000        10000            10,000.00     0
# 4      1075358    1311748       3000         3000             3,000.00     1
# 5      1075269    1311441       5000         5000             5,000.00     0
# 6      1069639    1304742       7000         7000             7,000.00     1
# 7      1072053    1288686       3000         3000             3,000.00     0
# 8      1071795    1306957       5600         5600             5,600.00     1
# 9      1071570    1306721       5375         5375             5,350.00     1
# 10     1070078    1305201       6500         6500             6,500.00     1
# ...

# %%
#The scikit-learn library provides the SelectKBest class that can be used with a suite of different statistical tests 
#to select a specific number of features
#We can now conclude that driving factors behind loan default are :
#1. total_rec_prncp	Principal received to date
#2. recoveries	post charge off gross recovery
#3. next_pymnt_d	Next scheduled payment date
#4. total_pymnt	Payments received to date for total amount funded
#5. collection_recovery_fee	post charge off collection fee
#6. funded_amnt	The total amount committed to that loan at that point in time.
#7. total_pymnt_inv	Payments received to date for portion of total amount funded by investors
#8. last_pymnt_d	Last month payment was received
#9. loan_amnt	The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
#10.funded_amnt_inv	The total amount committed by investors for that loan at that point in time.

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#df_num = loan_data.select_dtypes(include=[np.float,np.int8])
#do feature engineering only on numeric data

X = loandatanulldropcolumn  #independent columns
y = pd.DataFrame(loandatanulldropcolumn.loc[:,"loan_status"])

X = X.drop("loan_status",axis=1)

X = X.fillna(X.median())
#y.dtypes
df_num1 = X.select_dtypes(include=[np.float64]).columns
df_num1.shape
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
print(model)
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.show()
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# [0.00938536 0.00842691 0.04853774 0.06763065 0.03897408 0.02854221
#  0.00842428 0.04424533 0.00851514 0.01202471 0.00343046 0.0033354
#  0.00269387 0.00312241 0.00359263 0.00493989 0.         0.00528562
#  0.00348652 0.00342152 0.0037956  0.00370896 0.00382779 0.0019557
#  0.00352942 0.00365928 0.00348385 0.00211048 0.00353791 0.00402555
#  0.00349414 0.         0.07695942 0.05284598 0.05573277 0.05236906
#  0.16400359 0.02157486 0.00995317 0.08611267 0.06382033 0.01153711
# ...

# %%
#The scikit-learn library provides the SelectKBest class that can be used with a suite of different statistical tests 
#to select a specifloandatanulldropcolumnic number of features
#The scikit-learn library provides the SelectKBest class that can be used with a suite of different statistical tests 
#to select a specific number of features
#we can now conclude that the difference between funded loan amout and requested loan amount is depedent on following factors :
# 1. loan_amnt	The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# 2. total_pymnt	Payments received to date for total amount funded
# 3. total_pymnt_inv	Payments received to date for portion of total amount funded by investors
# 4  total_rec_prncp	Principal received to date

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
loandatanulldropcolumn["Full_Loan_Sanctioned"]=loandatanulldropcolumn.funded_amnt==loandatanulldropcolumn.loan_amnt
loandatanullremove = loandata.dropna(axis=1, how='all')
loandatanulldropcolumn=loandatanulldropcolumn.drop(["id","member_id"],axis=1)
#df_num = loan_data.select_dtypes(include=[np.float,np.int8])
#do feature engineering only on numeric data
#id column does not have any significance

X = loandatanulldropcolumn  #independent columns
y = pd.DataFrame(loandatanulldropcolumn.loc[:,"Full_Loan_Sanctioned"])
X = X.drop(["Full_Loan_Sanctioned","funded_amnt","installment"],axis=1)
#X =X.fillna(0)
#X = X.drop(["loan_status_category"],axis=1)
#X.mths_since_last_delinq
X = X.fillna(X.median())

from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) 
#use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')

plt.show()
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\ipykernel_launcher.py:34: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# [0.13762699 0.06379903 0.02686184 0.02784981 0.0198756  0.02376085
#  0.02005481 0.01817422 0.00998836 0.02170155 0.01484629 0.03895849
#  0.01550294 0.         0.04704327 0.01717482 0.02045885 0.01957434
#  0.01890644 0.02138173 0.00878651 0.02061677 0.01756727 0.01836727
#  0.00505256 0.02422718 0.02097541 0.02175526 0.         0.00346719
#  0.0037221  0.04135329 0.03768504 0.04851991 0.02546474 0.00563266
#  0.00713223 0.0065162  0.02100918 0.02311882 0.02036764 0.
# ...

# %%
#So we can now conclude that following columns are important ones so keeping only them
#1. total_rec_prncp	Principal received to dateloandata
#2. recoveries	post charge off gross recovery
#3. next_pymnt_d	Next scheduled payment date
#4. total_pymnt	Payments received to date for total amount funded
#5. collection_recovery_fee	post charge off collection fee
#6. funded_amnt	The total amount committed to that loan at that point in time.
#7. total_pymnt_inv	Payments received to date for portion of total amount funded by investors
#8. last_pymnt_d	Last month payment was received
#9. loan_amnt	The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
#10.funded_amnt_inv	The total amount committed by investors for that loan at that point in time.
loandata = pd.read_csv('loan.csv',encoding='utf-8')

loandata = loandata[["loan_amnt","out_prncp","last_pymnt_amnt","funded_amnt_inv","total_rec_prncp","recoveries","total_pymnt","collection_recovery_fee","funded_amnt","last_pymnt_d",]]
loandata
# Out:
# C:\Users\Rishi\Anaconda3\rishi_new\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        loan_amnt            out_prncp      last_pymnt_amnt  \
# 0           5000                 0.00               171.62
# 1           2500                 0.00               119.66
# 2           2400                 0.00               649.91
# 3          10000                 0.00               357.48
# 4           3000               524.06                67.79
# 5           5000                 0.00               161.03
# 6           7000                 0.00             1,313.76
# 7           3000                 0.00               111.34
# 8           5600                 0.00               152.39
# 9           5375                 0.00               121.45
# 10          6500                 0.00             1,655.54
# ...
